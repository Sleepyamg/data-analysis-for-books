# %%
import pandas as pd

# %%
data_set=pd.read_csv("C:/Users/LENOVO/Desktop/books.csv")
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1354 entries, 0 to 1353
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   book_id                    1354 non-null   int64
#  1   goodreads_book_id          1354 non-null   int64
#  2   best_book_id               1354 non-null   int64
#  3   work_id                    1354 non-null   int64
#  4   books_count                1354 non-null   int64
#  5   isbn                       1302 non-null   object
#  6   isbn13                     1310 non-null   float64
#  7   authors                    1354 non-null   object
#  8   original_publication_year  1351 non-null   float64
#  9   original_title             1302 non-null   object
#  10  title                      1354 non-null   object
#  11  language_code              1245 non-null   object
#  12  average_rating             1354 non-null   float64
# ...

# %%
data_set.describe()
# Out:
#            book_id  goodreads_book_id  best_book_id       work_id  \
# count  1354.000000       1.354000e+03  1.354000e+03  1.354000e+03
# mean   4453.584195       5.951852e+06  6.120589e+06  8.707028e+06
# std    2894.277455       6.664595e+06  6.935008e+06  9.813696e+06
# min       1.000000       1.000000e+00  1.000000e+00  1.150000e+02
# 25%    1860.250000       1.537868e+05  1.537962e+05  1.375035e+06
# 50%    4177.500000       3.305318e+06  3.422646e+06  4.005716e+06
# 75%    6814.500000       9.917380e+06  1.019388e+07  1.435717e+07
# max    9955.000000       3.207567e+07  3.360215e+07  4.963819e+07
#
#        books_count        isbn13  original_publication_year  average_rating  \
# count  1354.000000  1.310000e+03                1351.000000     1354.000000
# mean     50.330871  9.766700e+12                2003.422650        3.999357
# std      61.338867  3.572069e+11                  16.779301        0.224263
# ...

# %%
data_set.isnull().sum()
# Out:
# book_id                        0
# goodreads_book_id              0
# best_book_id                   0
# work_id                        0
# books_count                    0
# isbn                          52
# isbn13                        44
# authors                        0
# original_publication_year      3
# original_title                52
# title                          0
# language_code                109
# average_rating                 0
# ratings_count                  0
# work_ratings_count             0
# work_text_reviews_count        0
# ratings_1                      0
# ratings_2                      0
# ratings_3                      0
# ratings_4                      0
# ratings_5                      0
# image_url                      0
# small_image_url                0
# dtype: int64

# %%
print(data_set)
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           6           11870085      11870085  16827462          226
# 4          12           13335037      13335037  13155899          210
# ...       ...                ...           ...       ...          ...
# 1349     9925              86737         86737   3877968           52
# 1350     9937           13010211      13010211  18171867           22
# 1351     9942           16074758      16074758  21869436           18
# 1352     9947           21393526      21393526  40690062           19
# 1353     9955           13065327      13065327  18230950           25
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# ...

# %%
data_set['original_title'].fillna('empty', inplace=True)

# %%
harry_potter = data_set[data_set['original_title'].str.contains('Harry Potter', case=False)]
print(harry_potter)
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 1           2                  3             3   4640799          491
# 6          18                  5             5   2402163          376
# 8          21                  2             2   2809203          307
# 9          23              15881         15881   6231171          398
# 10         24                  6             6   3046572          332
# 11         25             136251        136251   2963218          263
# 12         27                  1             1  41335427          275
# 96        422             862041        862041   2962492           76
# 613      3753                 10            10  21457570            6
# 1036     7018             483445        483445    471792           42
#
#             isbn        isbn13                                  authors  \
# 1      439554934  9.780440e+12              J.K. Rowling, Mary GrandPré
# ...

# %%
harry_potter.describe()
# Out:
#            book_id  goodreads_book_id   best_book_id       work_id  \
# count    10.000000          10.000000      10.000000  1.000000e+01
# mean   1133.300000      149764.500000  149764.500000  8.832041e+06
# std    2372.878142      292756.296154  292756.296154  1.286720e+07
# min       2.000000           1.000000       1.000000  4.717920e+05
# 25%      21.500000           3.500000       3.500000  2.847525e+06
# 50%      24.500000           8.000000       8.000000  3.004895e+06
# 75%     323.250000      106158.500000  106158.500000  5.833578e+06
# max    7018.000000      862041.000000  862041.000000  4.133543e+07
#
#        books_count        isbn13  original_publication_year  average_rating  \
# count    10.000000  1.000000e+01                  10.000000       10.000000
# mean    256.600000  9.780459e+12                2001.300000        4.491000
# std     163.050231  4.547325e+07                   3.497618        0.220829
# ...

# %%
Hp=harry_potter[['books_count','average_rating','ratings_count','work_ratings_count','work_text_reviews_count','ratings_1','ratings_2','ratings_3','ratings_4','ratings_5']]
print(Hp)
# Out:
#       books_count  average_rating  ratings_count  work_ratings_count  \
# 1             491            4.44        4602479             4800065
# 6             376            4.53        1832823             1969375
# 8             307            4.46        1735368             1840548
# 9             398            4.37        1779331             1906199
# 10            332            4.53        1753043             1868642
# 11            263            4.61        1746574             1847395
# 12            275            4.54        1678823             1785676
# 96             76            4.74         190050              204125
# 613             6            4.73          24618               26274
# 1036           42            3.96          13820               15145
#
#       work_text_reviews_count  ratings_1  ratings_2  ratings_3  ratings_4  \
# 1                       75867      75504     101676     455024    1156318
# ...

# %%
bestselling_book = Hp.loc[Hp['books_count'].idxmax()]

print(bestselling_book)
# Out:
# books_count                    491.00
# average_rating                   4.44
# ratings_count              4602479.00
# work_ratings_count         4800065.00
# work_text_reviews_count      75867.00
# ratings_1                    75504.00
# ratings_2                   101676.00
# ratings_3                   455024.00
# ratings_4                  1156318.00
# ratings_5                  3011543.00
# Name: 1, dtype: float64

# %%
print("The best seller book",harry_potter.loc[1, 'original_title'])
# Out:
# The best seller book Harry Potter and the Philosopher's Stone

# %%
Hp.describe()
# Out:
#        books_count  average_rating  ratings_count  work_ratings_count  \
# count    10.000000       10.000000   1.000000e+01        1.000000e+01
# mean    256.600000        4.491000   1.535693e+06        1.626344e+06
# std     163.050231        0.220829   1.338120e+06        1.399453e+06
# min       6.000000        3.960000   1.382000e+04        1.514500e+04
# 25%     122.750000        4.445000   5.622432e+05        5.995128e+05
# 50%     291.000000        4.530000   1.740971e+06        1.843972e+06
# 75%     365.000000        4.592500   1.772759e+06        1.896810e+06
# max     491.000000        4.740000   4.602479e+06        4.800065e+06
#
#        work_text_reviews_count     ratings_1      ratings_2      ratings_3  \
# count                10.000000     10.000000      10.000000      10.000000
# mean              29302.600000  12498.500000   26248.400000  145720.400000
# std               23399.455664  22434.449023   29844.676198  136672.041798
# ...
